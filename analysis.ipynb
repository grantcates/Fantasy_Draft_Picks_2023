# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Loading in the Full Data
full_data = pd.read_csv("full_data.csv")

# %%
# Loading in the Data
summarized_view = pd.read_csv("summarized_view.csv")

# %% [markdown]
# Fantasy Draft Picks for 2023
# * Pictured below is a data table showing NFL players total yards in the year 2022.
# * This data table is recommending what players you should draft in your upcoming fantasy draft.
# * The data table is ascending by total yards.
# * The table is represented by the colors green, yellow, and red.
# -  Green - Players you should draft first round.
# - Yellow - Players you should draft rounds two through four.
# - Red - Players that will be more than likely drafted after the fourth round.

# %%
test1.head(50).style.background_gradient(axis=0, gmap=test1["Yards"], cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_40753_row0_col0, #T_40753_row0_col1, #T_40753_row0_col2, #T_40753_row0_col3, #T_40753_row0_col4, #T_40753_row0_col5, #T_40753_row0_col6, #T_40753_row0_col7, #T_40753_row0_col8, #T_40753_row0_col9, #T_40753_row0_col10, #T_40753_row0_col11 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_40753_row1_col0, #T_40753_row1_col1, #T_40753_row1_col2, #T_40753_row1_col3, #T_40753_row1_col4, #T_40753_row1_col5, #T_40753_row1_col6, #T_40753_row1_col7, #T_40753_row1_col8, #T_40753_row1_col9, #T_40753_row1_col10, #T_40753_row1_col11 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_40753_row2_col0, #T_40753_row2_col1, #T_40753_row2_col2, #T_40753_row2_col3, #T_40753_row2_col4, #T_40753_row2_col5, #T_40753_row2_col6, #T_40753_row2_col7, #T_40753_row2_col8, #T_40753_row2_col9, #T_40753_row2_col10, #T_40753_row2_col11 {
#   background-color: #afdd70;
#   color: #000000;
# }
# ...

# %%
plt.figure(figsize=(8, 6))

# Create a side-by-side box plot
sns.boxplot(x="Age", y="Yards", data=summarized_view)

# Customize the appearance
plt.title("NFL Side-by-Side Box Plot by Age")
plt.xlabel("Player Age")
plt.ylabel("Total Yards")

# Show the plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Figure 1
# - The visualization above is a side by side box plot represented by NFL players age and total yards in 2022.
# - This model is recommending that fantasy football owners should draft players between the ages of 22 and 30.
# - Players within those years are predcited to score more points for your fantasy football team's.
# - There are outliers in this dataset. This can be explained by rookies having a breakout season for their first year in the league.

# %%
# Create a copy of the dataset
plot_df = summarized_view.copy()
plt.figure(figsize=(8, 6))
team_TD = sns.barplot(x="Team", y="TD", data=plot_df.head(8), color="Red")
# Customize
plt.title("NFL Team by Total Touchdowns")
plt.xlabel("NFL Teams")
plt.ylabel("Total Touchdowns")

# Show plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Figure 2
# - The model above represnts NFL teams that recorded the most yards in 2022.
# - This bar plot is a complient to the offensive coordinator for the teams listed above.
# - For fantasy, I would recommed drafting any WR or RB from the teams listed above. There is a higher percentage of that player putting up points for your team.
# - Players from the Kansas City Cheifs and Buffalo Bills scored above average for fantasy points in the year 2022.

# %%
# Create a copy of the dataset
plot_df = summarized_view.copy()
plot_df.head(8)
plt.figure(figsize=(8, 6))
team_yards = sns.barplot(x="Team", y="Yards", data=plot_df.head(10), color="blue")
# Customize
plt.title("NFL Teams visualized by Total Yards")
plt.xlabel("NFL Teams")
plt.ylabel("Total yards")
# Show plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Figure 3
# - The model above represnts NFL teams that put up the most yards in the year of 2022.
# - Fantasy owners should draft WR's and RB's from the teams above
# - Teams to keep an eye on...
#     - Vikings
#     - Dolphins
#     - Bills
#     - Cheifs
#     - Raiders
#     - Cowboys

# %%
# Create a copy of the dataset
plot_df = summarized_view.copy()
plot_df.head(8)

plt.figure(figsize=(8, 6))


team_TD = sns.barplot(x="Player", y="Yards", data=plot_df.head(5), color="Green")


# Customize
plt.title("Top NFL Players by Total Yards")
plt.xlabel("NFL Players")
plt.ylabel("Total yards")

# Show plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %% [markdown]
# Figure 4
# - This bar chart represents the top fantasy scorers for the year 2022.
# - Fantasy owners should draft these players in round one, if available.
#     - Justin Jefferson (Vikings)
#     - Tyreek Hill (Dolphins)
#     - Travis Kelce (Cheifs)
#     - Stefon Diggs (Bills)
#     - Austin Ekeler (Chargers)
# - Honorable mentions
#     - Davante Adams (Raiders)
#     - CeeDee Lamb (Cowboys)
#     - Derrick Henry (Titans)

# %%
# Create a box plot using seaborn
sns.boxplot(data=summarized_view["Yards"], orient="h")

# Customize the appearance
plt.title("Total Yards Box Plot (WR/RB)")
plt.xlabel("Total Yards")

# Show the plot
plt.show()

# %% [markdown]
# Figure 5
# - This model is a box plot represetned by yards in the 2022 football season for WR's and RB's
# - From the visualization, majorty of the players collected between 50 to 400 yards in a season.
# - There are some outliers, which fanstasy owners should pay close attention to.
# - Players that have collected 400+ yards should be drafted in the first three rounds of the fantasy draft.
# - The more outliers that an owner acquires leads to a winning football team.
# - Also it increases the probability of winning your fantasy league.
